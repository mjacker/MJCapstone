# %% [markdown]
# # Setting up enviroments requirements
# If you want to run this Jupyter Notebook on Google colab, clieck on the next hyperlink: [Load on Google Colab.](https://githubtocolab.com/mjacker/MJCapstone/blob/develop/0_merged_ipynb_files_for_google_colab.ipynb)
#
# If you want to load the Jypyter Notebook locally then clone the github repository on [Github Repository](https://github.com/mjacker/MJCapstone/tree/develop) by yourself and prepare a venv python enviroment to install the requirements dependencies.
#
# Uncomment the next block to install dependencies.

# %% [markdown]
# ## Venv python enviroment

# %%
# !python -m pip install requirements.yml -y

# %% [markdown]
# ## Downloading the Dataset
# Downloading on Google colab. (By default)

# %%
# on linux
# !apt-get install awscli
# !python -m pip install requests==2.28.2
# !mkdir datasets
# !aws s3 ls --no-sign-request --region ap-northeast-3 "s3://cse-cic-ids2018/" --recursive --human-readable
# !aws s3 cp --no-sign-request --region ap-northeast-3 "s3://cse-cic-ids2018/Processed Traffic Data for ML Algorithms/Friday-02-03-2018_TrafficForML_CICFlowMeter.csv" "./datasets/"
# !aws s3 cp --no-sign-request --region ap-northeast-3 "s3://cse-cic-ids2018/Processed Traffic Data for ML Algorithms/Friday-16-02-2018_TrafficForML_CICFlowMeter.csv" "./datasets/"

# %% [markdown]
# Downloading on windows.

# %%
# Tested on windows 10
# On powershell 7.4

# !python -m pip install boto3
# !python download-cic-ids-dataset.py
# Out:
# Requirement already satisfied: boto3 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (1.29.6)
# Requirement already satisfied: botocore<1.33.0,>=1.32.6 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from boto3) (1.32.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from boto3) (0.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from botocore<1.33.0,>=1.32.6->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from botocore<1.33.0,>=1.32.6->boto3) (1.26.18)
# Requirement already satisfied: six>=1.5 in d:\_jaime\02 uptp\_clases\06 sexto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.33.0,>=1.32.6->boto3) (1.16.0)
# Dataset Friday-02-03-2018_TrafficForML_CICFlowMeter.csv already downloaded
# Dataset Friday-16-02-2018_TrafficForML_CICFlowMeter.csv already downloaded
