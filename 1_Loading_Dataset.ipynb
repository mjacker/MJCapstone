# %% [markdown]
# # Setting up enviroments requirements
#
# - Pandas

# %%
# Installing pandas
# !pip install pandas # en vez de installar uno a uno, mejor preparar un archivo de requirements.
import pandas as pd
print(pd.__version__)
# Out:
# Requirement already satisfied: pandas in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from pandas) (1.26.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\_jaime\02 uptp\_clases\05 quinto semestre\07 capsotne\07 code\mjcapstone\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# 2.1.1

# %% [markdown]
# # Getting the Dataset
# Since I am coding on a w10, commands can differs between w10 and linux, will be easier to load the dataset and environment on a hosted Jupyter Notebook.
#
# ### Google Colab
# https://colab.research.google.com/drive/17sxSvRFoAeJxdqxbNl7YeSLdxo_Wm_HZ?usp=sharing

# %%
# on w10
# !pip install awscli
# !pip install boto2

# %%
# on linux
# !awscli s3 ls --no-sign-request --region ap-northeast-3 "s3://cse-cic-ids2018/" --recursive --human-readable
# Out:
# ERROR: unknown command "awscli"
