# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.show()

# %%
import pandas as pd

df = pd.DataFrame()

print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# india china to canada migration 19980 to 1984
data = [[8880, 5123], [8670, 6682], [8147, 3308], [7338, 1863], [5704, 1527]]

df = pd.DataFrame(data, columns=["India", "China"])

print(df)
# Out:
#    India  China
# 0   8880   5123
# 1   8670   6682
# 2   8147   3308
# 3   7338   1863
# 4   5704   1527

# %%
df["India"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="line")
# Out:
# <Axes: >
