# %% [markdown]
# # Module 3
# - Pie Charts
# - Box plots
# - Scatter

# %%
# %matplotlib inline
import pandas as pd

# %%
df_canada = pd.read_csv("datasets/canadian_immegration_data.csv")
# adding index country to index
df_canada.index = df_canada['Country']

df_canada
# Out:
#                        Country Continent              Region  \
# Country
# Afghanistan        Afghanistan      Asia       Southern Asia
# Albania                Albania    Europe     Southern Europe
# Algeria                Algeria    Africa     Northern Africa
# American Samoa  American Samoa   Oceania           Polynesia
# Andorra                Andorra    Europe     Southern Europe
# ...                        ...       ...                 ...
# Viet Nam              Viet Nam      Asia  South-Eastern Asia
# Western Sahara  Western Sahara    Africa     Northern Africa
# Yemen                    Yemen      Asia        Western Asia
# Zambia                  Zambia    Africa      Eastern Africa
# Zimbabwe              Zimbabwe    Africa      Eastern Africa
#
#                            DevName  1980  1981  1982  1983  1984  1985  ...  \
# Country                                                                 ...
# Afghanistan     Developing regions    16    39    39    47    71   340  ...
# Albania          Developed regions     1     0     0     0     0     0  ...
# Algeria         Developing regions    80    67    71    69    63    44  ...
# American Samoa  Developing regions     0     1     0     0     0     0  ...
# Andorra          Developed regions     0     0     0     0     0     0  ...
# ...                            ...   ...   ...   ...   ...   ...   ...  ...
# Viet Nam        Developing regions  1191  1829  2162  3404  7583  5907  ...
# Western Sahara  Developing regions     0     0     0     0     0     0  ...
# Yemen           Developing regions     1     2     1     6     0    18  ...
# Zambia          Developing regions    11    17    11     7    16     9  ...
# Zimbabwe        Developing regions    72   114   102    44    32    29  ...
#
#                 2005  2006  2007  2008  2009  2010  2011  2012  2013  Total
# Country
# Afghanistan     3436  3009  2652  2111  1746  1758  2203  2635  2004  58639
# Albania         1223   856   702   560   716   561   539   620   603  15699
# Algeria         3626  4807  3623  4005  5393  4752  4325  3774  4331  69439
# American Samoa     0     1     0     0     0     0     0     0     0      6
# Andorra            0     1     1     0     0     0     0     1     1     15
# ...              ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# Viet Nam        1852  3153  2574  1784  2171  1942  1723  1731  2112  97146
# Western Sahara     0     1     0     0     0     0     0     0     0      2
# Yemen            161   140   122   133   128   211   160   174   217   2985
# Zambia            91    77    71    64    60   102    69    46    59   1677
# Zimbabwe         615   454   663   611   508   494   434   437   407   8598
#
# [195 rows x 39 columns]

# %%
# years = list[map(str, range(1980, 2014))]
years = list (map(str, range(1980, 2014)))

years
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\_Jaime\02 UPTP\_CLASES\05 QUINTO SEMESTRE\07 CAPSOTNE\07 Code\MJCapstone\08 Courses\Data Visualization\04 chapter 3 - box Plots.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/d%3A/_Jaime/02%20UPTP/_CLASES/05%20QUINTO%20SEMESTRE/07%20CAPSOTNE/07%20Code/MJCapstone/08%20Courses/Data%20Visualization/04%20chapter%203%20-%20box%20Plots.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib as mpl
#       <a href='vscode-notebook-cell:/d%3A/_Jaime/02%20UPTP/_CLASES/05%20QUINTO%20SEMESTRE/07%20CAPSOTNE/07%20Code/MJCapstone/08%20Courses/Data%20Visualization/04%20chapter%203%20-%20box%20Plots.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/d%3A/_Jaime/02%20UPTP/_CLASES/05%20QUINTO%20SEMESTRE/07%20CAPSOTNE/07%20Code/MJCapstone/08%20Courses/Data%20Visualization/04%20chapter%203%20-%20box%20Plots.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> df_continents['Total'].head()
#
# NameError: name 'df_continents' is not defined

# %%
df_japan = df_canada.loc[['Japan'], years].transpose()
print(df_japan)

df_japan.plot(kind='box')
plt.title("Immigration to Canada by Continent [1980-2013]")
plt.ylabel("Number of Immigrants")

plt.show()
# Out:
# Country  Japan
# 1980       701
# 1981       756
# 1982       598
# 1983       309
# 1984       246
# 1985       198
# 1986       248
# 1987       422
# 1988       324
# 1989       494
# 1990       379
# 1991       506
# 1992       605
# 1993       907
# 1994       956
# 1995       826
# 1996       994
# 1997       924
# 1998       897
# 1999      1083
# 2000      1010
# 2001      1092
# 2002       806
# 2003       817
# 2004       973
# 2005      1067
# 2006      1212
# 2007      1250
# 2008      1284
# 2009      1194
# 2010      1168
# 2011      1265
# 2012      1214
# 2013       982

# %% [markdown]
# # Scatter Plots

# %%
# df_tot = pd.DataFrame.copy(df_canada[years]).sum(axis=0)
# # change the years to type int (useful for regression later on)
# df_tot.index = map(int, df_tot.index)

# # reset the index to put in back in as a column in the df_tot dataframe
# # df_tot.reset_index(inplace = True)

# # rename columns
# df_tot.columns = ['year', 'total']

# # view the final dataframe
# df_tot.head()

# %%
# df_tot.plot(
#     kind='scatter',
#     x="year",
#     y='total'
# )
# plt.title("Total Immigrant population to Canada from 1980 -2013")
# plt.xlabel("Year")
# plt.ylabel("Number of Immigrants")
# plt.show()
